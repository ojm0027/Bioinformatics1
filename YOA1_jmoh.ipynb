# %% [markdown]
# Google drive 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/binfo1-work
# Out:
# /content/drive/MyDrive/binfo1-work

# %%
import pandas as pd
cnts = pd.read_csv('read-counts.txt', sep='\t', comment='#', index_col=0)
cnts.head()
# Out:
#                                                      Chr  \
# Geneid
# ENSMUSG00000102693.2                                chr1
# ENSMUSG00000064842.3                                chr1
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# ENSMUSG00000102851.2                                chr1
# ENSMUSG00000103377.2                                chr1
#
#                                                                   Start  \
# Geneid
# ENSMUSG00000102693.2                                            3143476
# ENSMUSG00000064842.3                                            3172239
# ENSMUSG00000051951.6  3276124;3276746;3283662;3283832;3284705;349192...
# ENSMUSG00000102851.2                                            3322980
# ENSMUSG00000103377.2                                            3435954
#
#                                                                     End  \
# Geneid
# ENSMUSG00000102693.2                                            3144545
# ...

# %%
cnts['clip_enrichment'] = cnts['CLIP-35L33G.bam'] / cnts['RNA-control.bam']
cnts['rden_change'] = (cnts['RPF-siLin28a.bam'] / cnts['RNA-siLin28a.bam']) / (cnts['RPF-siLuc.bam'] / cnts['RNA-siLuc.bam'])
cnts.head()
# Out:
#                                                      Chr  \
# Geneid
# ENSMUSG00000102693.2                                chr1
# ENSMUSG00000064842.3                                chr1
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# ENSMUSG00000102851.2                                chr1
# ENSMUSG00000103377.2                                chr1
#
#                                                                   Start  \
# Geneid
# ENSMUSG00000102693.2                                            3143476
# ENSMUSG00000064842.3                                            3172239
# ENSMUSG00000051951.6  3276124;3276746;3283662;3283832;3284705;349192...
# ENSMUSG00000102851.2                                            3322980
# ENSMUSG00000103377.2                                            3435954
#
#                                                                     End  \
# Geneid
# ENSMUSG00000102693.2                                            3144545
# ...

# %%
cnts = cnts.reset_index()  # 기존 index가 Geneid로 들어감

# %%
cnts['Geneid_clean'] = cnts['Geneid'].str.replace(r'\.\d+$', '', regex=True)

# %%
cnts.head()
# Out:
#                  Geneid                                 Chr  \
# 0  ENSMUSG00000102693.2                                chr1
# 1  ENSMUSG00000064842.3                                chr1
# 2  ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# 3  ENSMUSG00000102851.2                                chr1
# 4  ENSMUSG00000103377.2                                chr1
#
#                                                Start  \
# 0                                            3143476
# 1                                            3172239
# 2  3276124;3276746;3283662;3283832;3284705;349192...
# 3                                            3322980
# 4                                            3435954
#
#                                                  End         Strand  Length  \
# 0                                            3144545              +    1070
# 1                                            3172348              +     110
# ...

# %% [markdown]
# 여기까진  Guided Mission 1의 결과 -----------------

# %% [markdown]
# 연구 제목
# *   CLIP 및 Ribosome Profiling 데이터 기반의 Gene Ontology term-enrichment analysis
# ![KakaoTalk_Photo_2025-05-29-12-17-01.png](data:image/png;base64,...)

# %% [markdown]
# CLIP 및 Ribosome Profiling 기반 GO term-enrichment 분석
#
# *   LIN28A 결합 강도(CLIP) 및 번역 효율 변화(RPF)를 유전자 단위로 정량화
#
# *   각 유전자를 GO term에 매핑하여 기능 단위로 통합 분석
#
# *   GO term별 평균 clip_enrichment (x축), 평균 rden_change (y축) 계산
# *   주요 GO term에 대해 번역 조절 패턴을 Figure 5A 스타일로 시각화
